# %%
import os
import shutil

# ------- WHITELIST -------
allowed_folders = {
    "Trayce_Jackson_Davis",
    "Andre_Drummond",
    "Buddy_Hield",
    "Angelo_Russell",
    "Joel_Embiid",
    "Paul_George",
    "Kyrie_Irving",
    "Jayson_Tatum",
    "Caleb_Martin",
    "Andrew_Wiggins",
    "Max_Fiedler",
    "OG_Anunoby",
    "Anthony_Davis",
    "Jaylen_Brown",
    "Victor_Wembanyama",
    "Jrue_Holiday",
    "Austin_Reaves",
    "Kevin_Love",
    "Giannis_Antetokounmpo",
    "Stephen_Curry",
    "Isiah_Thomas",
    "Al_Horford",
    "Magic_Johnson",
    "Tyler_Herro",
    "Duncan_Robinson",
    "Kyle_Anderson",
    "Cade_Cunningham",
    "LeBron_James",
    "Tim_Duncan",
    "Jimmy_Butler",
    "Kevon_Looney",
    "Zach_LaVine",
    "Jaden_Ivey",
    "Kyle_Lowry",
    "Michael_Jordan",
    "Devin_Booker",
    "Draymond_Green",
    "Zach_Collins",
    "Jonathan_Kuminga",
    "Anthony_Edwards",
    "Lonzo_Ball",
    "Jaime_Jaquez",
    "Ausar_Thompson",
    "Jalen_Brunson",
    "Shaquille_O'Neal",
    "Kobe_Bryant",
    "Chris_Paul",
    "Harrison_Barnes",
    "Kevin_Durant",
    "Bam_Adebayo"


}

# ------- TARGET DIRECTORY -------
target_dir = os.path.abspath(r"../exp_datalake/sampled/wikitext/output")

print("Target directory:", target_dir)

# ------- DELETE LOGIC -------
for item in os.listdir(target_dir):
    item_path = os.path.join(target_dir, item)

    if os.path.isdir(item_path) and item not in allowed_folders:
        print(f"Deleting folder: {item}")
        shutil.rmtree(item_path)

print("Done.")
# Out:
# Target directory: d:\Fadhil\Pelajaran\Riset\ACE\Reproduce\QUEST-R0\exp_datalake\sampled\wikitext\output
# Deleting folder: ..._Thirteen_Years_Later
# Deleting folder: 10_@.@_6_°_compared_to_7_°_for_Mercury_and_17_°_for_Pluto_)_and_moderately_eccentric_(_e
# Deleting folder: 130th_Engineer_Brigade_(_United_States_)
# Deleting folder: 14_@.@_1_years_)_,_115mCd_(_t1_2
# Deleting folder: 1806_Great_Coastal_hurricane
# Deleting folder: 1888_–_89_New_Zealand_Native_football_team
# Deleting folder: 1933_Treasure_Coast_hurricane
# Deleting folder: 1939_Pacific_hurricane_season
# Deleting folder: 1940_Atlantic_hurricane_season
# Deleting folder: 1955_Atlantic_hurricane_season
# Deleting folder: 1973_Atlantic_hurricane_season
# Deleting folder: 1981_European_Cup_Final
# Deleting folder: 1981_Peach_Bowl_(_January_)
# Deleting folder: 1985_Rajneeshee_assassination_plot
# Deleting folder: 1986_Peach_Bowl
# Deleting folder: 1990_Pacific_hurricane_season
# Deleting folder: 1998_National_League_Wild_Card_tie_@-@_breaker_game
# Deleting folder: 1_henry_and_capacitance_C
# Deleting folder: 1_rad_s_and_a_nominal_impedance_k
# Deleting folder: 2003_Pacific_typhoon_season
# Deleting folder: 2007_Hawaii_Bowl
# Deleting folder: 2008_Bahrain_Grand_Prix
# Deleting folder: 2010_Alabama_Crimson_Tide_football_team
# Deleting folder: 2010_Claxton_Shield
# Deleting folder: 2010_Haiti_earthquake
# Deleting folder: 2011_–_12_Columbus_Blue_Jackets_season
# Deleting folder: 2011_–_12_Michigan_Wolverines_men_'s_basketball_team
# Deleting folder: 2013_–_14_York_City_F.C._season
# Deleting folder: 2016_Spanish_Grand_Prix
# Deleting folder: 2nd_Battalion_9th_Marines
# Deleting folder: 2_4th_Machine_Gun_Battalion_(_Australia_)
# Deleting folder: 766th_Independent_Infantry_Regiment_(_North_Korea_)
# Deleting folder: 76ers
# Deleting folder: 7_2_)_suppresses_the_superconductivity_,_which_is_induced_by_eliminating_this_local_moment_(_J
# Deleting folder: 7_Independent_Company_(_Rhodesia_)
# Deleting folder: A4232_road
# Deleting folder: Ace_Attorney
# Deleting folder: Action_of_13_September_1810
# Deleting folder: Acute_myeloid_leukemia
# Deleting folder: Adams_River_(_British_Columbia_)
# Deleting folder: Adam_Stansfield
# Deleting folder: Adjustments_Penalties_,_Pts
# Deleting folder: Aerith_Gainsborough
# Deleting folder: AIL_Storm
# Deleting folder: Air_Rhodesia_Flight_825
# Deleting folder: Alice_in_Chains
# Deleting folder: Allah
# Deleting folder: Amanita_muscaria
# Deleting folder: American_Beauty_(_1999_film_)
# Deleting folder: Amylostereum
# Deleting folder: Ancient_Egyptian_deities
# Deleting folder: and
# Deleting folder: Andrew_Johnston_(_singer_)
# Deleting folder: Anekantavada
# Deleting folder: Angel_of_Death_(_Slayer_song_)
# Deleting folder: Antimony
# Deleting folder: Arbeideren_(_Hamar_)
# Deleting folder: Architecture_of_the_Song_dynasty
# Deleting folder: Arihant_@-@_class_submarine
# Deleting folder: Arikamedu
# Deleting folder: Arizona_State_Route_67
# Deleting folder: Arnhem_Oosterbeek_War_Cemetery
# Deleting folder: Art_in_Medieval_Scotland
# Deleting folder: Art_Ross
# Deleting folder: Aston_Villa_F.C_
# Deleting folder: Astraeus_hygrometricus
# Deleting folder: Atlanta
# Deleting folder: Attalea_(_palm_)
# Deleting folder: August_(_Fringe_)
# Deleting folder: Awakening_(_Star_Trek___Enterprise_)
# Deleting folder: A_Month_in_the_Country_(_film_)
# Deleting folder: Back_Off_Boogaloo
# Deleting folder: Back_to_Tennessee_(_song_)
# Deleting folder: Baltimore_mayoral_election_,_1999
# Deleting folder: Banai_(_goddess_)
# Deleting folder: Banksia_violacea
# Deleting folder: Barbarian_II___The_Dungeon_of_Drax
# Deleting folder: Bart_vs._Australia
# Deleting folder: Bassline_(_Chris_Brown_song_)
# Deleting folder: Bath_Assembly_Rooms
# Deleting folder: Batting_points_,_Bwl
# Deleting folder: Battle_of_Binh_Gia
# Deleting folder: Battle_of_Dürenstein
# Deleting folder: Battle_of_Edson_'s_Ridge
# Deleting folder: Battle_of_Hubbardton
# Deleting folder: Battle_of_Merville_Gun_Battery
# Deleting folder: Battle_of_Romani
# Deleting folder: Battle_of_Sullivan_'s_Island
# Deleting folder: Battle_of_Tellicherry
# Deleting folder: Battle_of_the_Hongorai_River
# Deleting folder: Ben_Amos
# Deleting folder: Berg_(_station_)
# Deleting folder: Berhtwald
# Deleting folder: Berkley_Bedell
# Deleting folder: Biddenden_Maids
# Deleting folder: Big_Boy_(_song_)
# Deleting folder: Bintulu
# Deleting folder: Blackburn_Firecrest
# Deleting folder: Blackwyche
# Deleting folder: Black_@-@_tailed_jackrabbit
# Deleting folder: Blazers
# Deleting folder: Bob_Dylan
# Deleting folder: Bodyline
# Deleting folder: Boise_National_Forest
# Deleting folder: Bossy_(_Lindsay_Lohan_song_)
# Deleting folder: Boston
# Deleting folder: Boy_@-@_Scoutz_'_n_the_Hood
# Deleting folder: Brad_Stevens
# Deleting folder: Brandon_Minor
# Deleting folder: Brock_Lesnar
# Deleting folder: Bucks
# Deleting folder: Bulls
# Deleting folder: Burn
# Deleting folder: Burning_of_women_in_England
# Deleting folder: Burns_'_Heir
# Deleting folder: Business_School_(_The_Office_)
# Deleting folder: Butterfly_World_Tour
# Deleting folder: B_of_the_Bang
# Deleting folder: Cadmium
# Deleting folder: California_State_Route_243
# Deleting folder: Calvin_McCarty
# Deleting folder: Cambodian_Campaign
# Deleting folder: Canning_Dam
# Deleting folder: Capel_Lligwy
# Deleting folder: Cape_lobster
# Deleting folder: Carre_'s_Grammar_School
# Deleting folder: Cater_2_U
# Deleting folder: Caught_Up_(_Usher_song_)
# Deleting folder: Cavaliers
# Deleting folder: Cell_nucleus
# Deleting folder: Celtics
# Deleting folder: Central_Area_Command_(_RAAF_)
# Deleting folder: Ceratopsia
# Deleting folder: Ceres_(_dwarf_planet_)
# Deleting folder: Chad_at_the_2008_Summer_Olympics
# Deleting folder: Chagas_disease
# Deleting folder: Chapter_1_(_House_of_Cards_)
# Deleting folder: Charles_@-@_Valentin_Alkan
# Deleting folder: Charles_Eaton_(_RAAF_officer_)
# Deleting folder: Charlotte
# Deleting folder: Charmbracelet
# Deleting folder: Chasing_Vermeer
# Deleting folder: Chicago
# Deleting folder: Christine_Hakim
# Deleting folder: Christmas_1994_nor_'easter
# Deleting folder: Christopher_Gore
# Deleting folder: Chris_Turner_(_American_football_)
# Deleting folder: Church_of_Christ_Pantocrator_,_Nesebar
# Deleting folder: Cicely_Mary_Barker
# Deleting folder: Civilian_Public_Service
# Deleting folder: Clayton_Kershaw
# Deleting folder: Clay_Bennett
# Deleting folder: Cleveland
# Deleting folder: Clippers
# Deleting folder: Clocks_(_song_)
# Deleting folder: Coldrum_Long_Barrow
# Deleting folder: Cole_Hamels
# Deleting folder: Comair_Flight_5191
# Deleting folder: Come_What_(_ever_)_May
# Deleting folder: Commonwealth_War_Graves_Commission
# Deleting folder: Common_starling
# Deleting folder: Condom
# Deleting folder: Constant_k_filter
# Deleting folder: Copia_(_museum_)
# Deleting folder: Corn_crake
# Deleting folder: Corpus_Christi_Bay
# Deleting folder: Corythosaurus
# Deleting folder: Cougar
# Deleting folder: Crash_Boom_Bang_!
# Deleting folder: Crazy_in_Love
# Deleting folder: Croatian_independence_referendum_,_1991
# Deleting folder: Crosby_Garrett_Helmet
# Deleting folder: Crown_Fountain
# Deleting folder: Crush_(_video_game_)
# Deleting folder: Curtis_Woodhouse
# Deleting folder: Cyclone_Graham
# Deleting folder: Cyclone_Herbie
# Deleting folder: Dallas
# Deleting folder: Dangerously_in_Love_Tour
# Deleting folder: Daniel_Radcliffe
# Deleting folder: Dan_DeVos
# Deleting folder: Dan_Gilbert
# Deleting folder: Dave_Sisler
# Deleting folder: Daydream_(_Mariah_Carey_album_)
# Deleting folder: December_1964_South_Vietnamese_coup
# Deleting folder: Denver
# Deleting folder: Derfflinger_@-@_class_battlecruiser
# Deleting folder: Detroit
# Deleting folder: Development_of_Fez
# Deleting folder: Devin_Townsend
# Deleting folder: De_dezas_a_espwa___interviews_with_persons_affected_by_the_2010_Haiti_earthquake
# Deleting folder: Diamond_stingray
# Deleting folder: Dick_Rifenburg
# Deleting folder: Die_Another_Day
# Deleting folder: Directed_acyclic_graph
# Deleting folder: Djedkare_Isesi
# Deleting folder: Domnall_mac_Murchada
# Deleting folder: Don_'t_Take_It_Personally_,_Babe_,_It_Just_Ain_'t_Your_Story
# Deleting folder: Don_'t_You_Wanna_Stay
# Deleting folder: Dota_2
# Deleting folder: Dover_Athletic_F.C_
# Deleting folder: Draining_and_development_of_the_Everglades
# Deleting folder: DuMont_Television_Network
# Deleting folder: Du_Fu
# Deleting folder: Dvorak_technique
# Deleting folder: E._W._Hornung
# Deleting folder: Edward_Creutz
# Deleting folder: Ed_Barrow
# Deleting folder: Elephanta_Caves
# Deleting folder: Elgin_Cathedral
# Deleting folder: England_national_rugby_union_team
# Deleting folder: Ernie_Cooksey
# Deleting folder: Erving_Goffman
# Deleting folder: Etymology_of_Wicca
# Deleting folder: Europium
# Deleting folder: Eva_Perón
# Deleting folder: Exit_Through_the_Kwik_@-@_E_@-@_Mart
# Deleting folder: Exploration_of_Jupiter
# Deleting folder: Far_Away_Places_(_Mad_Men_)
# Deleting folder: Fastra_II
# Deleting folder: Fear_of_Flying_(_The_Simpsons_)
# Deleting folder: Fernando_Torres
# Deleting folder: Fern_Hobbs
# Deleting folder: Fieldfare
# Deleting folder: First_@-@_move_advantage_in_chess
# Deleting folder: First_Battle_of_Maryang_San
# Deleting folder: First_Light_(_Rebecca_Stead_novel_)
# Deleting folder: First_Mongol_invasion_of_Burma
# Deleting folder: First_Ostend_Raid
# Deleting folder: Flash_Gordon_Strange_Adventure_Magazine
# Deleting folder: Florida_Atlantic_University
# Deleting folder: Florida_State_Road_878
# Deleting folder: Forbidden_Fruit_(_J._Cole_song_)
# Deleting folder: Fort_Glanville_Conservation_Park
# Deleting folder: Fort_Scott_National_Historic_Site
# Deleting folder: Forward_Intelligence_Team
# Deleting folder: Frank_Headlam
# Deleting folder: Frank_Slide
# Deleting folder: Freakum_Dress
# Deleting folder: Frederick_Reines
# Deleting folder: Free_Derry
# Deleting folder: French_cruiser_Sully
# Deleting folder: G.I._Joe___Retaliation
# Deleting folder: Gaboon_viper
# Deleting folder: Galentine_'s_Day
# Deleting folder: Galveston_,_Texas
# Deleting folder: Gambia_women_'s_national_football_team
# Deleting folder: Games_Played_;_TOI
# Deleting folder: Gayle_Benson
# Deleting folder: General_aviation_in_the_United_Kingdom
# Deleting folder: Geopyxis_carbonaria
# Deleting folder: George_Calvert_,_1st_Baron_Baltimore
# Deleting folder: George_N._Briggs
# Deleting folder: Georgian_scripts
# Deleting folder: Gerard_(_archbishop_of_York_)
# Deleting folder: German_Type_UB_I_submarine
# Deleting folder: Gertrude_Barrows_Bennett
# Deleting folder: Ghost_in_the_Shell_(_1995_film_)
# Deleting folder: Ghost_in_the_Shell___Stand_Alone_Complex_-_Solid_State_Society
# Deleting folder: Giacomo_Meyerbeer
# Deleting folder: Glorious_First_of_June
# Deleting folder: Goals_;_A
# Deleting folder: God_'s_Choice
# Deleting folder: God_of_War_video_game_collections
# Deleting folder: Gold_Beach
# Deleting folder: Gold_dollar
# Deleting folder: Grade_I_listed_buildings_in_Somerset
# Deleting folder: Grammy_Award_for_Best_Concept_Music_Video
# Deleting folder: Greens_Ledge_Light
# Deleting folder: Gregorian_Tower
# Deleting folder: Gregory_Helms
# Deleting folder: Grizzlies
# Deleting folder: Guitar_Hero
# Deleting folder: Hadji_Ali
# Deleting folder: Haifa
# Deleting folder: Halo___Uprising
# Deleting folder: Hannah_Dodd
# Deleting folder: Hannah_Primrose_,_Countess_of_Rosebery
# Deleting folder: Harajuku_Lovers_Tour
# Deleting folder: Harold_Innis
# Deleting folder: Hawks
# Deleting folder: Ha_'_K_'in_Xook
# Deleting folder: Head_VI
# Deleting folder: Heat
# Deleting folder: Hed_PE
# Deleting folder: Hellblazer
# Deleting folder: Hemmema
# Deleting folder: Henry_Hoʻolulu_Pitman
# Deleting folder: Henry_of_Grosmont_,_1st_Duke_of_Lancaster
# Deleting folder: Herb_Simon
# Deleting folder: Hibiscus_(_restaurant_)
# Deleting folder: High_Five_Interchange
# Deleting folder: History_of_artificial_intelligence
# Deleting folder: History_of_Braathens_SAFE_(_1946_–_93_)
# Deleting folder: History_of_Bradford_City_A.F.C_
# Deleting folder: Hi_,_Infidelity
# Deleting folder: HMS_Black_Prince_(_1904_)
# Deleting folder: HMS_Boreas_(_H77_)
# Deleting folder: HMS_Comet_(_H00_)
# Deleting folder: HMS_Hostile_(_H55_)
# Deleting folder: HMS_Marlborough_(_1912_)
# Deleting folder: Homarus_gammarus
# Deleting folder: Home_Made_Mince_Pie
# Deleting folder: Hoover_Dam
# Deleting folder: Hope_Highway
# Deleting folder: Hornets
# Deleting folder: Horrible_Bosses
# Deleting folder: Houston
# Deleting folder: Hoysala_literature
# Deleting folder: Hoyt_Wilhelm
# Deleting folder: Hugh_Foliot
# Deleting folder: Hugh_Walpole
# Deleting folder: Humpty_Dumpty
# Deleting folder: Hurricane_Abby_(_1960_)
# Deleting folder: Hurricane_Beatriz_(_2011_)
# Deleting folder: Hurricane_Dot_(_1959_)
# Deleting folder: Hurricane_Felicia_(_2009_)
# Deleting folder: Hurricane_Flossy_(_1956_)
# Deleting folder: Hurricane_Ingrid
# Deleting folder: Hurricane_Lorenzo_(_2007_)
# Deleting folder: Hurricane_Omar_(_2008_)
# Deleting folder: Hurricane_Tanya_(_1995_)
# Deleting folder: Hurricane_Uleki
# Deleting folder: Hu_Zhengyan
# Deleting folder: Hydnellum_peckii
# Deleting folder: If_I_Never_See_Your_Face_Again
# Deleting folder: Iguanodon
# Deleting folder: Illinois_(_Sufjan_Stevens_album_)
# Deleting folder: Imagine_(_John_Lennon_song_)
# Deleting folder: Imagism
# Deleting folder: Independence_Day_(_India_)
# Deleting folder: Independiente_(_Ricardo_Arjona_album_)
# Deleting folder: Indianapolis
# Deleting folder: Inglewood
# Deleting folder: Inocybe_praetervisa
# Deleting folder: Invisible_rail
# Deleting folder: In_Bloom
# Deleting folder: Ireland
# Deleting folder: Ironclad_warship
# Deleting folder: Irresistible_(_The_X_@-@_Files_)
# Deleting folder: Isabella_Beeton
# Deleting folder: Ise_@-@_class_battleship
# Deleting folder: Islais_Creek
# Deleting folder: Italian_cruiser_Aretusa
# Deleting folder: I_Am_Unicorn
# Deleting folder: J._C._W._Beckham
# Deleting folder: Jack_and_Jill_(_nursery_rhyme_)
# Deleting folder: Jacob_deGrom
# Deleting folder: Jacqueline_Fernandez
# Deleting folder: James_Dolan
# Deleting folder: James_Nesbitt
# Deleting folder: James_Robert_Baker
# Deleting folder: Jane_'s_Attack_Squadron
# Deleting folder: Jane_Dudley_,_Duchess_of_Northumberland
# Deleting folder: Japanese_battleship_Asahi
# Deleting folder: Jazz
# Deleting folder: Jenova_Chen
# Deleting folder: Jeremi_Wiśniowiecki
# Deleting folder: Jerry_Reinsdorf
# Deleting folder: Jessie_Stephen
# Deleting folder: Jifna
# Deleting folder: Jin_–_Song_Wars
# Deleting folder: Joe_Lacob
# Deleting folder: Joe_Nathan
# Deleting folder: Johnny_McNichol
# Deleting folder: Johnson_–_Corey_–_Chaykovsky_reaction
# Deleting folder: John_Cullen
# Deleting folder: John_of_Brienne
# Deleting folder: Josce_de_Dinan
# Deleting folder: Josepha_Petrick_Kemarre
# Deleting folder: Joseph_Tsai
# Deleting folder: Josh_Harris
# Deleting folder: Journey_(_2012_video_game_)
# Deleting folder: Joyful_,_Joyful
# Deleting folder: June_1941_uprising_in_eastern_Herzegovina
# Deleting folder: Kaboom_(_Parks_and_Recreation_)
# Deleting folder: Kaimanawa_horse
# Deleting folder: Kakapo
# Deleting folder: Kalyanasundara
# Deleting folder: Karamokho_Alfa
# Deleting folder: Katherine_Pulaski
# Deleting folder: Kedok_Ketawa
# Deleting folder: Key_(_basketball_)
# Deleting folder: Khoo_Kheng_@-@_Hor
# Deleting folder: Kings
# Deleting folder: Kirby_'s_Block_Ball
# Deleting folder: Kir_'Shara
# Deleting folder: Kiss_You_(_One_Direction_song_)
# Deleting folder: Kitsune
# Deleting folder: Knicks
# Deleting folder: Krak_des_Chevaliers
# Deleting folder: Kyra_(_Charmed_)
# Deleting folder: K_@-@_22_(_Kansas_highway_)
# Deleting folder: L.A.M.B_
# Deleting folder: Laborintus_II_(_2012_recording_)
# Deleting folder: Lactarius_indigo
# Deleting folder: Lady_in_the_Lake_trial
# Deleting folder: Lakers
# Deleting folder: Landing_at_Anzac_Cove
# Deleting folder: Languedoc_@-@_Roussillon_wine
# Deleting folder: Last_Exit_on_Brooklyn
# Deleting folder: Laurence_Olivier
# Deleting folder: Leanne_Del_Toso
# Deleting folder: Leg_before_wicket
# Deleting folder: Leslie_Andrew
# Deleting folder: Le_souper_de_Beaucaire
# Deleting folder: Light_Tank_Mk_VII_Tetrarch
# Deleting folder: LiSA_(_Japanese_musician_,_born_1987_)
# Deleting folder: Lisa_the_Simpson
# Deleting folder: Little_Gidding_(_poem_)
# Deleting folder: Liu_Kang
# Deleting folder: Live_&_Kicking
# Deleting folder: Livin_'_the_Dream
# Deleting folder: Lloyd_Mathews
# Deleting folder: Lock_Haven_,_Pennsylvania
# Deleting folder: Loose_(_Nelly_Furtado_album_)
# Deleting folder: Losses_,_D
# Deleting folder: Losses_,_T
# Deleting folder: Lost_Horizons_(_Lemon_Jelly_album_)
# Deleting folder: Los_Angeles
# Deleting folder: Loverboy_(_Mariah_Carey_song_)
# Deleting folder: Love_Me_Like_You
# Deleting folder: Lágrimas_Cálidas
# Deleting folder: Magadheera
# Deleting folder: Maggie_Simpson
# Deleting folder: Magic
# Deleting folder: Manila
# Deleting folder: Man_Down_(_song_)
# Deleting folder: Marauders_(_Star_Trek___Enterprise_)
# Deleting folder: Mariana_(_poem_)
# Deleting folder: Mark_Cuban
# Deleting folder: Mark_Stockwell
# Deleting folder: Marshall_Applewhite
# Deleting folder: Martin_Keamy
# Deleting folder: Maryland_Route_194
# Deleting folder: Mavericks
# Deleting folder: Max_Mosley
# Deleting folder: McAllister_Tower_Apartments
# Deleting folder: Mega_Man_&_Bass
# Deleting folder: Memory_Almost_Full
# Deleting folder: Memphis
# Deleting folder: Meralda_Warren
# Deleting folder: Meridian_,_Mississippi
# Deleting folder: Mexico_City_Metropolitan_Cathedral
# Deleting folder: Miami
# Deleting folder: Michelle_Rzepecki
# Deleting folder: Micky_Arison
# Deleting folder: Middle_Colonies
# Deleting folder: Midge_(_Barbie_)
# Deleting folder: Military_history_of_Australia
# Deleting folder: Military_history_of_Gibraltar_during_World_War_II
# Deleting folder: Milwaukee
# Deleting folder: Minneapolis
# Deleting folder: Missouri_River
# Deleting folder: Miss_Meyers
# Deleting folder: Mitsuyo_Maeda
# Deleting folder: Mogadishu
# Deleting folder: Mole_cricket
# Deleting folder: Moment_of_Surrender
# Deleting folder: Monty_Can_'t_Buy_Me_Love
# Deleting folder: Moro_River_Campaign
# Deleting folder: Mortimer_Wheeler
# Deleting folder: Mothers_of_the_Disappeared
# Deleting folder: Mount_Elbert
# Deleting folder: Mount_Jackson_(_Antarctica_)
# Deleting folder: Mozambican_War_of_Independence
# Deleting folder: Mumia_Abu_@-@_Jamal
# Deleting folder: Murder_of_Tom_ap_Rhys_Pryce
# Deleting folder: Music_of_Chrono_Cross
# Deleting folder: Mutinus_elegans
# Deleting folder: Mycena_galericulata
# Deleting folder: Mycena_inclinata
# Deleting folder: My_Boo_(_Usher_and_Alicia_Keys_song_)
# Deleting folder: M_@-@_108_(_Michigan_highway_)
# Deleting folder: M_@-@_114_(_Michigan_highway_)
# Deleting folder: M_@-@_122_(_Michigan_highway_)
# Deleting folder: M_@-@_47_(_Michigan_highway_)
# Deleting folder: M_@-@_5_(_Michigan_highway_)
# Deleting folder: M_@-@_6_(_Michigan_highway_)
# Deleting folder: M_@-@_81_(_Michigan_highway_)
# Deleting folder: M_@-@_82_(_Michigan_highway_)
# Deleting folder: Nazarov_cyclization_reaction
# Deleting folder: Nebraska_Highway_88
# Deleting folder: Nero
# Deleting folder: Nerva
# Deleting folder: Nets
# Deleting folder: New_Jersey_Route_29
# Deleting folder: New_Jersey_Route_50
# Deleting folder: New_Jersey_Route_65
# Deleting folder: New_Orleans
# Deleting folder: New_Year_'s_Eve_(_Up_All_Night_)
# Deleting folder: New_York_City
# Deleting folder: New_York_State_Route_164
# Deleting folder: New_York_State_Route_185
# Deleting folder: New_York_State_Route_31B
# Deleting folder: New_York_State_Route_368
# Deleting folder: New_York_State_Route_38
# Deleting folder: New_York_State_Route_448
# Deleting folder: New_York_State_Route_93
# Deleting folder: Nicole_Franklin
# Deleting folder: Nina_Simone
# Deleting folder: No._20_Squadron_RAAF
# Deleting folder: No._79_Wing_RAAF
# Deleting folder: Noisy_miner
# Deleting folder: NoitulovE
# Deleting folder: Norman_Finkelstein
# Deleting folder: Norsk_Spisevognselskap
# Deleting folder: North_@-@_Eastern_Area_Command_(_RAAF_)
# Deleting folder: Not_Quite_Hollywood___The_Wild_,_Untold_Story_of_Ozploitation_!
# Deleting folder: No_result_,_Pts
# Deleting folder: Nuggets
# Deleting folder: Odaenathus
# Deleting folder: Ode_on_Indolence
# Deleting folder: Ode_to_a_Nightingale
# Deleting folder: Odyssey_Number_Five
# Deleting folder: Of_Human_Feelings
# Deleting folder: Ohio_State_Route_319
# Deleting folder: Oklahoma_City
# Deleting folder: Oldham
# Deleting folder: Old_Baltimore_Pike
# Deleting folder: Old_Pine_Church
# Deleting folder: Olmec_colossal_heads
# Deleting folder: Ontario_Highway_36
# Deleting folder: On_the_Pulse_of_Morning
# Deleting folder: Operation_Eastern_Exit
# Deleting folder: Operation_USA
# Deleting folder: Oribi
# Deleting folder: Orlando
# Deleting folder: Osbert_de_Bayeux
# Deleting folder: Otra_Nota
# Deleting folder: Ouw_Peh_Tjoa
# Deleting folder: Overtime_Losses_;_GA
# Deleting folder: Oxaziridine
# Deleting folder: O_'Brien_@-@_class_destroyer
# Deleting folder: Pacers
# Deleting folder: Papal_conclave_,_1769
# Deleting folder: Papa_Stour
# Deleting folder: Paranthodon
# Deleting folder: Parliament_Act_1911
# Deleting folder: Partington
# Deleting folder: Patriarchal_Cathedral_of_the_Holy_Ascension_of_God
# Deleting folder: Pattycake_(_gorilla_)
# Deleting folder: Paul_Thomas_Anderson
# Deleting folder: Pelicans
# Deleting folder: Perfect_Dark_(_2010_video_game_)
# Deleting folder: Perry_the_Platypus
# Deleting folder: Philadelphia
# Deleting folder: Phoenix
# Deleting folder: Pistons
# Deleting folder: Plain_maskray
# Deleting folder: Played_,_W
# Deleting folder: Plum_cake
# Deleting folder: Plunketts_Creek_(_Loyalsock_Creek_)
# Deleting folder: Points_;_PIM
# Deleting folder: Pokiri
# Deleting folder: Polish_culture_during_World_War_II
# Deleting folder: Politics_of_Croatia
# Deleting folder: Polka_Party_!
# Deleting folder: Portland
# Deleting folder: Portrait_of_Monsieur_Bertin
# Deleting folder: Portuguese_ironclad_Vasco_da_Gama
# Deleting folder: Position_;_GP
# Deleting folder: President_Evil
# Deleting folder: Principe_Amedeo_@-@_class_ironclad
# Deleting folder: Project_Chanology
# Deleting folder: Protein
# Deleting folder: Protomycena
# Deleting folder: Qedarite
# Deleting folder: QuackShot
# Deleting folder: Rachel_Green
# Deleting folder: Raid_on_Manila_(_1798_)
# Deleting folder: Rakie_Ayola
# Deleting folder: Randy_Blythe_manslaughter_case
# Deleting folder: Raptors
# Deleting folder: Rebbie_Jackson
# Deleting folder: Residence_of_the_United_States_Ambassador_to_the_United_Nations
# Deleting folder: Rhode_Island_Route_4
# Deleting folder: Richard_Cresswell
# Deleting folder: Richard_Nixon_presidential_campaign_,_1968
# Deleting folder: Rio_de_Janeiro_bid_for_the_2016_Summer_Olympics
# Deleting folder: Road_to_the_North_Pole
# Deleting folder: Robbie_Fowler
# Deleting folder: Robert_Boulter
# Deleting folder: Rob_Howard
# Deleting folder: Rockets
# Deleting folder: Rockstar_101
# Deleting folder: Rocky_Mountain_Horse
# Deleting folder: Roger_Federer
# Deleting folder: Romanian_Land_Forces
# Deleting folder: Rosemary_'s_Baby_(_30_Rock_)
# Deleting folder: Route_261_(_Delaware_–_Pennsylvania_)
# Deleting folder: Roxas_(_Kingdom_Hearts_)
# Deleting folder: Royal_prerogative_in_the_United_Kingdom
# Deleting folder: Réunion_ibis
# Deleting folder: S.R._819
# Deleting folder: Sacramento
# Deleting folder: Sailor_Mouth
# Deleting folder: Saint_Leonard_Catholic_Church_(_Madison_,_Nebraska_)
# Deleting folder: Salt_Lake_City
# Deleting folder: Sandwich_Day
# Deleting folder: Sang_Pencerah
# Deleting folder: Santa_@-@_Fe_(_Bob_Dylan_song_)
# Deleting folder: San_Antonio
# Deleting folder: San_Francisco
# Deleting folder: Saprang_Kalayanamitr
# Deleting folder: Sarnia
# Deleting folder: Saves_;_Sv_%
# Deleting folder: Scientology_in_Germany
# Deleting folder: Sclerodermatineae
# Deleting folder: Second_Battle_of_Naktong_Bulge
# Deleting folder: Sentence_spacing
# Deleting folder: Shackleton_(_crater_)
# Deleting folder: Shaoguan_incident
# Deleting folder: Shikamaru_Nara
# Deleting folder: Sholay
# Deleting folder: Silver_Bullet_(_roller_coaster_)
# Deleting folder: Simon_Bradstreet
# Deleting folder: Simon_de_Montfort_'s_Parliament
# Deleting folder: Sinclair_Sovereign
# Deleting folder: Sister_Wives
# Deleting folder: Skye
# Deleting folder: Slammiversary_(_2008_)
# Deleting folder: SMS_Erzherzog_Ferdinand_Max
# Deleting folder: SMS_Markgraf
# Deleting folder: SMS_Zrínyi
# Deleting folder: SM_U_@-@_3_(_Austria_@-@_Hungary_)
# Deleting folder: Snow_(_visual_novel_)
# Deleting folder: Somerset_County_Cricket_Club_in_2009
# Deleting folder: Something_Borrowed_(_Torchwood_)
# Deleting folder: Sonic_the_Hedgehog_(_1991_video_game_)
# Deleting folder: Sorraia
# Deleting folder: Sorry_(_Madonna_song_)
# Deleting folder: South_of_Heaven
# Deleting folder: Sovetsky_Soyuz_@-@_class_battleship
# Deleting folder: Soviet_cruiser_Krasnyi_Kavkaz
# Deleting folder: Spanish_Hill
# Deleting folder: Species_(_film_)
# Deleting folder: Species_of_Allosaurus
# Deleting folder: Spurs
# Deleting folder: SS_El_Sol
# Deleting folder: Stanley_Green
# Deleting folder: Stanley_Price_Weir
# Deleting folder: Stan_Kroenke
# Deleting folder: Star
# Deleting folder: Stay_@-@_at_@-@_home_dad
# Deleting folder: Stefan_Wever
# Deleting folder: Stephanolepis_cirrhifer
# Deleting folder: Steve_Ballmer
# Deleting folder: Stop_!_!_Hibari_@-@_kun_!
# Deleting folder: Strand_,_London
# Deleting folder: Stuart_McCall
# Deleting folder: St_Caffo_'s_Church_,_Llangaffo
# Deleting folder: St_Mary_'s_Church_,_Nether_Alderley
# Deleting folder: St_Mary_'s_Church_,_Rhodogeidio
# Deleting folder: St_Nazaire_Raid
# Deleting folder: St_Peulan_'s_Church_,_Llanbeulan
# Deleting folder: Subtropical_Storm_Alpha_(_1972_)
# Deleting folder: Suns
# Deleting folder: Superman___Escape_from_Krypton
# Deleting folder: Super_Mario_Land
# Deleting folder: Super_Science_Stories
# Deleting folder: Survivor_Series_(_1992_)
# Deleting folder: Sweet_Love_(_Chris_Brown_song_)
# Deleting folder: T._Arthur_Cottam
# Deleting folder: T30_Howitzer_Motor_Carriage
# Deleting folder: Tales_of_Destiny_2
# Deleting folder: Tatwine
# Deleting folder: Tautiška_giesmė
# Deleting folder: Tawny_nurse_shark
# Deleting folder: Temnospondyli
# Deleting folder: Temple_Beth_Israel_(_Eugene_,_Oregon_)
# Deleting folder: Temple_of_Eshmun
# Deleting folder: Ten_Commandments_in_Catholic_theology
# Deleting folder: Territorial_era_of_Minnesota
# Deleting folder: Tessa_Noël
# Deleting folder: Texas_A_&_M_Singing_Cadets
# Deleting folder: Thelnetham_Windmill
# Deleting folder: There_'s_Got_to_Be_a_Way
# Deleting folder: The_Actor_'s_Children
# Deleting folder: The_Amps
# Deleting folder: The_Archaeology_of_Ritual_and_Magic
# Deleting folder: The_Boat_Race_1900
# Deleting folder: The_Boat_Race_1999
# Deleting folder: The_Boat_Race_2008
# Deleting folder: The_Bourgeois_Blues
# Deleting folder: The_Clean_Tech_Revolution
# Deleting folder: The_Convict_(_1910_film_)
# Deleting folder: The_Crab_with_the_Golden_Claws
# Deleting folder: The_Dreamscape
# Deleting folder: The_Family_Jewels_(_Marina_and_the_Diamonds_album_)
# Deleting folder: The_Feast_of_the_Goat
# Deleting folder: The_Food_Album
# Deleting folder: The_Fox_,_the_Wolf_and_the_Husbandman
# Deleting folder: The_General_in_His_Labyrinth
# Deleting folder: The_Goat_Puzzle
# Deleting folder: The_Good_Terrorist
# Deleting folder: The_Heart_of_Ezra_Greer
# Deleting folder: The_Hustler_(_film_)
# Deleting folder: The_Importance_of_Being_Earnest
# Deleting folder: The_Litigators
# Deleting folder: The_Magdalen_Reading
# Deleting folder: The_Moth_(_Lost_)
# Deleting folder: The_One_I_Love_(_manga_)
# Deleting folder: The_Portage_to_San_Cristobal_of_A.H_
# Deleting folder: The_Remix_(_Lady_Gaga_album_)
# Deleting folder: The_Same_Old_Story
# Deleting folder: The_Secret_(_The_Office_)
# Deleting folder: The_Secret_of_Monkey_Island
# Deleting folder: The_Sixth_Extinction
# Deleting folder: The_Snowmen
# Deleting folder: The_Son_Also_Draws
# Deleting folder: The_Stolen_Eagle
# Deleting folder: The_Tempest_(_album_)
# Deleting folder: The_Tramp_Dentists
# Deleting folder: The_Wave_(_Miike_Snow_song_)
# Deleting folder: Thomas_Quiney
# Deleting folder: Thom_Darden
# Deleting folder: Thunder
# Deleting folder: Thunderbirds_(_TV_series_)
# Deleting folder: Tiber_Oil_Field
# Deleting folder: Ties_,_A
# Deleting folder: Ties_,_L
# Deleting folder: Tikal
# Deleting folder: Tilman_Fertitta
# Deleting folder: Timberwolves
# Deleting folder: Tim_Richmond
# Deleting folder: Tina_Fey
# Deleting folder: Tintin_in_the_Congo
# Deleting folder: Tommy_Lawton
# Deleting folder: Tom_Gores
# Deleting folder: Toniná
# Deleting folder: Toronto
# Deleting folder: Toronto_Magnetic_and_Meteorological_Observatory
# Deleting folder: Tower_Building_of_the_Little_Rock_Arsenal
# Deleting folder: Track_and_field
# Deleting folder: Training_Day_(_The_Office_)
# Deleting folder: Transit_of_Venus
# Deleting folder: Transportation_in_Omaha
# Deleting folder: Treaty_of_Ciudad_Juárez
# Deleting folder: Trees_(_poem_)
# Deleting folder: Trials_and_Tribble_@-@_ations
# Deleting folder: Trinsey_v._Pennsylvania
# Deleting folder: Tristan_(_horse_)
# Deleting folder: Tropical_Storm_Abby_(_1964_)
# Deleting folder: Tropical_Storm_Brenda_(_1960_)
# Deleting folder: Tropical_Storm_Domoina
# Deleting folder: Tropical_Storm_Josephine_(_2008_)
# Deleting folder: Tropical_Storm_Jose_(_2005_)
# Deleting folder: Tropical_Storm_Olaf_(_1997_)
# Deleting folder: Trout_Creek_Mountains
# Deleting folder: True_Blue_(_Madonna_song_)
# Deleting folder: Truth_in_Numbers__
# Deleting folder: Tupolev_Tu_@-@_12
# Deleting folder: Type_94_Nambu_pistol
# Deleting folder: Typhoon_Imbudo
# Deleting folder: Typhoon_Krosa_(_2013_)
# Deleting folder: U.S._Route_2_in_Michigan
# Deleting folder: U2_concert_in_Sarajevo
# Deleting folder: Ulysses_(_poem_)
# Deleting folder: Underneath_(_The_X_@-@_Files_)
# Deleting folder: Until_the_Whole_World_Hears
# Deleting folder: Upsilon_Andromedae_b
# Deleting folder: USS_Atlanta_(_1861_)
# Deleting folder: USS_Breese_(_DD_@-@_122_)
# Deleting folder: USS_Illinois_(_BB_@-@_7_)
# Deleting folder: USS_O_'Brien_(_DD_@-@_51_)
# Deleting folder: Utah_State_Route_61
# Deleting folder: Valkyria_Chronicles_III
# Deleting folder: Van_Morrison___Too_Late_to_Stop_Now
# Deleting folder: Varanasi
# Deleting folder: Verpa_bohemica
# Deleting folder: View_of_the_World_from_9th_Avenue
# Deleting folder: Vistara
# Deleting folder: Vitamin_D_(_Glee_)
# Deleting folder: Voyage___Inspired_by_Jules_Verne
# Deleting folder: Wales_national_rugby_union_team
# Deleting folder: Ward_Churchill
# Deleting folder: Warriors
# Deleting folder: Washington
# Deleting folder: Washington_State_Route_221
# Deleting folder: Washington_State_Route_516
# Deleting folder: WASP_@-@_13b
# Deleting folder: WASP_@-@_44
# Deleting folder: Waterfall_Gully_,_South_Australia
# Deleting folder: Weather_buoy
# Deleting folder: Weevils_Wobble_But_They_Don_'t_Go_Down
# Deleting folder: Welsh_National_Opera
# Deleting folder: Westminster_Assembly
# Deleting folder: West_End_Girls
# Deleting folder: West_Hendford_Cricket_Ground_,_Yeovil
# Deleting folder: We_'ll_Always_Have_Paris_(_Star_Trek___The_Next_Generation_)
# Deleting folder: Where_the_Streets_Have_No_Name
# Deleting folder: White_Dog_(_Gary_novel_)
# Deleting folder: Who_Am_I_(_Casting_Crowns_song_)
# Deleting folder: Why_Does_It_Hurt_So_Bad
# Deleting folder: Wilhelm_Busch
# Deleting folder: Winston_Tunnel
# Deleting folder: Wins_;_L
# Deleting folder: Wizards
# Deleting folder: World_War_I_Memorial_(_East_Providence_,_Rhode_Island_)
# Deleting folder: World_War_Z
# Deleting folder: Wrapped_in_Red
# Deleting folder: Xenon
# Deleting folder: Yamaha_NS_@-@_10
# Deleting folder: Yoko_Shimomura
# Deleting folder: Youth_on_the_Prow_,_and_Pleasure_at_the_Helm
# Deleting folder: You_'re_Gonna_Love_Tomorrow
# Deleting folder: You_Only_Live_Twice_(_film_)
# Deleting folder: Yo_@-@_Yo_(_Nicola_Roberts_song_)
# Deleting folder: Zagreb_Synagogue
# Deleting folder: Zhou_Tong_(_archer_)
# Deleting folder: Zrinski_Battalion
# Deleting folder: Zygoballus_sexpunctatus
# Deleting folder: Ælfric_of_Abingdon
# Deleting folder: Éva_Gauthier
# Deleting folder: Ímar_mac_Arailt
# Done.
